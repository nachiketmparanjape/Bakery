# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_bakery = pd.read_csv('Hourly_bakery_data.csv')

# %%
df_bakery.head()
# Out:
#         Date Time  Hour of Day  Number_of_customers  \
# 0  11/3/2014 0:00            0                    4
# 1  11/3/2014 1:00            1                    2
# 2  11/3/2014 2:00            2                    2
# 3  11/3/2014 3:00            3                    3
# 4  11/3/2014 4:00            4                    4
#
#    Average_revenue_per_customer
# 0                          5.35
# 1                          3.28
# 2                          5.84
# 3                          3.56
# 4                          4.61

# %%
df_bakery['Total_Revenue'] = df_bakery['Number_of_customers']*df_bakery['Average_revenue_per_customer']
df_bakery['Profit'] = (0.7*df_bakery['Total_Revenue'] - 10 - 20)
df_bakery.head()
# Out:
#         Date Time  Hour of Day  Number_of_customers  \
# 0  11/3/2014 0:00            0                    4
# 1  11/3/2014 1:00            1                    2
# 2  11/3/2014 2:00            2                    2
# 3  11/3/2014 3:00            3                    3
# 4  11/3/2014 4:00            4                    4
#
#    Average_revenue_per_customer  Total_Revenue  Profit
# 0                          5.35          21.40 -15.020
# 1                          3.28           6.56 -25.408
# 2                          5.84          11.68 -21.824
# 3                          3.56          10.68 -22.524
# 4                          4.61          18.44 -17.092

# %%
group = df_bakery.groupby(['Hour of Day']).mean()
group
# Out:
#              Number_of_customers  Average_revenue_per_customer  Total_Revenue  \
# Hour of Day
# 0                            3.0                         2.778          8.832
# 1                            2.2                         3.632          8.212
# 2                            2.0                         4.308          7.992
# 3                            3.0                         3.452         10.004
# 4                            4.2                         4.194         18.980
# 5                           16.0                         3.944         64.110
# 6                           27.2                         4.894        132.362
# 7                           53.2                         5.326        284.224
# 8                           62.4                         5.474        341.212
# 9                           41.2                         5.600        229.980
# 10                          45.6                         4.952        225.156
# 11                          35.0                         4.310        150.904
# 12                          25.8                         4.324        113.590
# 13                          24.0                         3.646         87.724
# 14                          29.4                         3.860        110.494
# 15                          36.4                         4.402        157.970
# 16                          28.6                         3.976        114.756
# 17                          24.0                         3.784         90.874
# 18                          17.0                         3.218         54.916
# 19                          17.8                         4.572         81.068
# 20                           9.6                         3.880         39.394
# 21                           9.2                         4.524         42.430
# 22                           6.8                         3.892         29.074
# 23                           5.2                         4.454         23.502
#
#                Profit
# Hour of Day
# 0            -23.8176
# 1            -24.2516
# 2            -24.4056
# 3            -22.9972
# 4            -16.7140
# 5             14.8770
# 6             62.6534
# 7            168.9568
# 8            208.8484
# 9            130.9860
# 10           127.6092
# 11            75.6328
# 12            49.5130
# 13            31.4068
# 14            47.3458
# 15            80.5790
# 16            50.3292
# 17            33.6118
# 18             8.4412
# 19            26.7476
# 20            -2.4242
# 21            -0.2990
# 22            -9.6482
# 23           -13.5486

# %%
group.plot(y= ["Number_of_customers"])
plt.savefig("Customers_per_Hour")

# %%
group.plot(y= ["Total_Revenue"],color='red')
plt.savefig("Revenue_per_Hour")

# %%
group.plot(y= ["Average_revenue_per_customer"],color='black')
plt.savefig("Revenue_Per_Customer_Hourly")

# %%
total = group["Total_Revenue"].sum()

# %%
peak = group["Total_Revenue"][20:23].sum()

pct = peak/total
pct
# Out:
# 0.04567914456124164

# %%
max_profit = group["Profit"].max()
max_profit
# Out:
# 208.84839999999994

# %%
group
# Out:
#              Number_of_customers  Average_revenue_per_customer  Total_Revenue  \
# Hour of Day
# 0                            3.0                         2.778          8.832
# 1                            2.2                         3.632          8.212
# 2                            2.0                         4.308          7.992
# 3                            3.0                         3.452         10.004
# 4                            4.2                         4.194         18.980
# 5                           16.0                         3.944         64.110
# 6                           27.2                         4.894        132.362
# 7                           53.2                         5.326        284.224
# 8                           62.4                         5.474        341.212
# 9                           41.2                         5.600        229.980
# 10                          45.6                         4.952        225.156
# 11                          35.0                         4.310        150.904
# 12                          25.8                         4.324        113.590
# 13                          24.0                         3.646         87.724
# 14                          29.4                         3.860        110.494
# 15                          36.4                         4.402        157.970
# 16                          28.6                         3.976        114.756
# 17                          24.0                         3.784         90.874
# 18                          17.0                         3.218         54.916
# 19                          17.8                         4.572         81.068
# 20                           9.6                         3.880         39.394
# 21                           9.2                         4.524         42.430
# 22                           6.8                         3.892         29.074
# 23                           5.2                         4.454         23.502
#
#                Profit
# Hour of Day
# 0            -23.8176
# 1            -24.2516
# 2            -24.4056
# 3            -22.9972
# 4            -16.7140
# 5             14.8770
# 6             62.6534
# 7            168.9568
# 8            208.8484
# 9            130.9860
# 10           127.6092
# 11            75.6328
# 12            49.5130
# 13            31.4068
# 14            47.3458
# 15            80.5790
# 16            50.3292
# 17            33.6118
# 18             8.4412
# 19            26.7476
# 20            -2.4242
# 21            -0.2990
# 22            -9.6482
# 23           -13.5486

# %%
group.plot(y="Profit")
plt.savefig("Profit!")
